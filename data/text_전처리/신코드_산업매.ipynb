# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# CSV 불러오기
mapping = pd.read_csv("/content/drive/MyDrive/25-1/공모전/신코드_산업분류_매핑.csv")

# %%
mapping.head(200)
# Out:
#     신코드     mapping
# 0     1  백화점·유통·도소매
# 1     2  백화점·유통·도소매
# 2     3  백화점·유통·도소매
# 3     5   화학·에너지·환경
# 4     6   화학·에너지·환경
# ..  ...         ...
# 72   95       생산·제조
# 73   96       뷰티·미용
# 74   97         NaN
# 75   98         NaN
# 76   99    공기업·공공기관
#
# [77 rows x 2 columns]

# %%
import pandas as pd

industry_mapping = {
            "농업": "백화점·유통·도소매",
            "임업": "백화점·유통·도소매",
            "어업": "백화점·유통·도소매",
            "석탄, 원유 및 천연가스 광업": "화학·에너지·환경",
            "금속 광업": "화학·에너지·환경",
            "비금속광물 광업;연료용 제외": "화학·에너지·환경",
            "광업 지원 서비스업": "사무·경영지원",
            "식료품 제조업": "음식료·외식·프랜차이즈",
            "음료 제조업": "음식료·외식·프랜차이즈",
            "담배 제조업": "생산·제조",
            "섬유제품 제조업; 의복제외": "섬유·의류·패션",
            "의복, 의복액세서리 및 모피제품 제조업": "섬유·의류·패션",
            "가죽, 가방 및 신발 제조업": "섬유·의류·패션",
            "목재 및 나무제품 제조업;가구제외": "건축·설비",
            "펄프, 종이 및 종이제품 제조업" : "생산·제조",
            "인쇄 및 기록매체 복제업": "출판·인쇄·사진",
            "코크스, 연탄 및 석유정제품 제조업": "화학·에너지·환경",
            "화학물질 및 화학제품 제조업;의약품 제외": "화학·에너지·환경",
            "의료용 물질 및 의약품 제조업": "제약·보건·바이오",
            "고무 및 플라스틱제품 제조업": "생산·제조",
            "비금속 광물제품 제조업": "생산·제조",
            "1차 금속 제조업": "생산·제조",
            "금속가공제품 제조업;기계 및 가구 제외": "생산·제조",
            "전자부품, 컴퓨터, 영상, 음향 및 통신장비 제조업": "전자·기계",
            "의료, 정밀, 광학기기 및 시계 제조업": "전자·기계",
            "전기장비 제조업": "전자·기계",
            "기타 기계 및 장비 제조업": "전자·기계",
            "자동차 및 트레일러 제조업": "자동차·조선·철강·항공",
            "기타 운송장비 제조업": "자동차·조선·철강·항공",
            "가구 제조업": "생산·제조",
            "기타 제품 제조업": "생산·제조",
            "산업용 기계 및 장비 수리업": "전자·기계",
            "전기, 가스, 증기 및 공기 조절 공급업": "건축·설비",
            "수도업": "건축·설비",
            "하수, 폐수 및 분뇨 처리업": "건축·설비",
            "폐기물 수집, 운반, 처리 및 원료 재생업": "화학·에너지·환경",
            "환경 정화 및 복원업": "화학·에너지·환경",
            "종합 건설업": "건축·설비",
            "전문직별 공사업": "건축·설비",
            "자동차 및 부품 판매업": "백화점·유통·도소매",
            "도매 및 상품 중개업": "백화점·유통·도소매",
            "소매업; 자동차 제외": "백화점·유통·도소매",
            "육상 운송 및 파이프라인 운송업": "무역·물류·배송",
            "수상 운송업": "무역·물류·배송",
            "항공 운송업": "무역·물류·배송",
            "창고 및 운송관련 서비스업": "무역·물류·배송",
            "숙박업": "호텔·여행·항공",
            "음식점 및 주점업": "음식료·외식·프랜차이즈",
            "출판업": "출판·인쇄·사진",
            "영상ㆍ오디오 기록물 제작 및 배급업": "방송·케이블·프로덕션",
            "방송업": "방송·케이블·프로덕션",
            "우편 및 통신업": "네트워크·통신서비스",
            "컴퓨터 프로그래밍, 시스템 통합 및 관리업": "SW",
            "정보서비스업": "SW",
            "금융업": "은행·금융",
            "보험 및 연금업": "은행·금융",
            "금융 및 보험관련 서비스업": "은행·금융",
            "부동산업": "부동산·중개·임대",
            "연구개발업": "솔루션·SI·CRM·ERP",
            "전문 서비스업": "회계·세무·법무",
            "건축 기술, 엔지니어링 및 기타 과학기술 서비스업": "건축·설비",
            "기타 전문, 과학 및 기술 서비스업": "디자인·CAD",
            "사업시설 관리 및 조경 서비스업": "시설관리자·기타",
            "사업 지원 서비스업": "서치펌·헤드헌팅",
            "임대업; 부동산 제외": "백화점·유통·도소매",
            "공공 행정, 국방 및 사회보장 행정": "공기업·공공기관",
            "교육 서비스업": "교육",
            "보건업": "의료(간호·원무·상담)",
            "사회복지 서비스업": "사회복지·요양",
            "창작, 예술 및 여가관련 서비스업": "연예·엔터테인먼트",
            "스포츠 및 오락관련 서비스업": "연예·엔터테인먼트",
            "협회 및 단체": "공기업·공공기관",
            "개인 및 소비용품 수리업": "생산·제조",
            "기타 개인 서비스업": "뷰티·미용",
            "가구 내 고용활동": "",
            "달리 분류되지 않은 자가 소비를 위한 가구의 재화 및 서비스 생산활동": "",
            "국제 및 외국기관": "공기업·공공기관"
}

# mapping 컬럼 업데이트 (산업명 기준으로 변경, 없으면 기존 값 유지)
mapping["mapping"] = mapping["산업명"].map(industry_mapping).fillna(mapping["mapping"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '산업명'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-aafd000e3a6a> in <cell line: 0>()
#      82
#      83 # mapping 컬럼 업데이트 (산업명 기준으로 변경, 없으면 기존 값 유지)
# ...

# %%
mapping[mapping['신코드'] == 17]
# Out:
# Empty DataFrame
# Columns: [신코드, 산업명, mapping]
# Index: []

# %%
# 결과 확인
mapping.head(100)

# 1. '태그', '작성월' 컬럼 삭제
mapped = mapping.drop(columns=["산업명"], errors="ignore")

# 2. CSV 파일로 저장
mapped.to_csv("신코드_산업분류_매핑.csv", index=False, encoding="utf-8-sig")
